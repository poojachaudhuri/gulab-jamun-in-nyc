# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
df = pd.read_csv('price.csv')
df
# Out:
#                                name    zip  zip.1  quantity  rating  \
# 0                             Gazab  10002  10002       2.0     4.5
# 1            Punjabi Grocery & Deli  10009  10009       NaN     4.5
# 2          Maharaja Sweets & Snacks  11372  11372       2.0     3.5
# 3                    Shaheen Sweets  11423  11423       7.0     4.5
# 4                           GupShup  10003  10003       3.0     4.0
# 5          Bengal Tiger Indian Food  10019  10019       2.0     4.5
# 6               Omar's Fine Cuisine  11238  11238       2.0     5.0
# 7                            Ananda  10012  10012       2.0     4.0
# 8     Clove Indian Restaurant & Bar  10031  10031       2.0     4.0
# 9     Al Naimat Restaurant & Sweets  11372  11372       2.0     4.0
# 10       Malai Marke Indian Cuisine  10003  10003       2.0     4.0
# 11                     Paratha Wala  11375  11375       2.0     4.5
# 12            Atithi Indian Cuisine  11249  11249       2.0     5.0
# 13             Dhaba Indian Cuisine  10016  10016       2.0     3.5
# 14              Kathiyawadi Kitchen   8872   8872       4.0     4.0
# 15             Patiala Indian Grill  10001  10001       2.0     4.5
# 16                     Masala Grill  11217  11217       2.0     3.5
# 17                          Benares  10007  10007       2.0     4.0
# 18                      Khiladi NYC  10009  10009       NaN     4.5
# 19          Raja Sweets & Fast Food  11372  11372       2.0     4.0
# 20                          Nanking  11420  11420       2.0     4.0
# 21                         Tamarind  10013  10013       2.0     4.0
# 22             India at Time Square  10036  10036       2.0     4.5
# 23       Dhania Fine Indian Cuisine  11216  11216       2.0     4.5
# 24                      Mint Masala  10012  10012       2.0     4.0
# 25      Desi Deli Indian Restaurant  10019  10019       2.0     3.5
# 26       Mint Heights - Fort Greene  11205  11205       2.0     4.5
# 27                    Spice & Grill  11205  11205       2.0     4.0
# 28          Angel Indian Restaurant  11372  11372       2.0     4.5
# 29                   Curry In Handi  11206  11206       2.0     4.5
# 30                        Dhabewala   6905   6905       4.0     4.5
# 31      Premium Sweets & Restaurant  10462  10462       2.0     4.5
# 32                            Sathi  10003  10003       2.0     4.5
# 33                    Mughlai Grill  10002  10002       2.0     4.5
# 34  Mint Heights - Brooklyn Heights  11201  11201       2.0     4.5
# 35                          Pippali  10016  10016       NaN     4.0
# 36                 Moti Mahal Delux  10065  10065       2.0     4.0
# 37                          Namaste  11217  11217       3.0     4.5
# 38   Masala Times Greenwich Village  10012  10012       2.0     4.0
# 39                          Paisley  10013  10013       2.0     4.5
# 40  Kitchen Grill Indian Restaurant  11238  11238       2.0     4.5
# 41                       Tribhaanga  10019  10019       2.0     5.0
# 42                            Sahib  10016  10016       2.0     4.0
# 43          Surya Sweets and Snacks  11426  11426       NaN     3.5
#
#                     comments
# 0                        NaN
# 1   Availibility unconfirmed
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18      Jamun Sundae for $12
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# 30                       NaN
# 31                       NaN
# 32                       NaN
# 33                       NaN
# 34                       NaN
# 35      Price not mentioned
# 36                       NaN
# 37                       NaN
# 38                       NaN
# 39                       NaN
# 40                       NaN
# 41                       NaN
# 42                       NaN
# 43      Price not mentioned

# %%
# %%R
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# %%R
#
# # Read data
# df <- read_csv('price.csv')
# df
# Out:
# Rows: 44 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): name, price, price_norm, comments
# dbl (3): zip, quantity, rating
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 44 × 7
#    name                            zip price quantity price_norm rating comments
#    <chr>                         <dbl> <chr>    <dbl> <chr>       <dbl> <chr>
#  1 Gazab                         10002 $6.00        2 $3.00         4.5 <NA>
#  2 Punjabi Grocery & Deli        10009 <NA>        NA <NA>          4.5 Availib…
#  3 Maharaja Sweets & Snacks      11372 $3.00        2 1.5           3.5 <NA>
#  4 Shaheen Sweets                11423 $9.00        7 1.28          4.5 <NA>
#  5 GupShup                       10003 $8.00        3 2.67          4   <NA>
#  6 Bengal Tiger Indian Food      10019 $5.00        2 2.5           4.5 <NA>
#  7 Omar's Fine Cuisine           11238 $4.99        2 2.49          5   <NA>
#  8 Ananda                        10012 $6.99        2 3.49          4   <NA>
#  9 Clove Indian Restaurant & Bar 10031 $5.00        2 2.5           4   <NA>
# 10 Al Naimat Restaurant & Sweets 11372 $3.00        2 1.5           4   <NA>
# # … with 34 more rows
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R -w 1400 -h 1500
#
# ggplot(df) +
#     aes(x=price, y=name) +
#     geom_point(col="tomato2", size=3) +
#     geom_segment(aes(x=price,
#                         xend=price,
#                         y=min(name),
#                         yend=max(name)),
#                     linetype="dashed",
#                     size=0.1)

# %%
# this is terrible
# i should plot the price as value for money
# i.e. the price maybe low for some restaurants but the food is not good and vice-versa
